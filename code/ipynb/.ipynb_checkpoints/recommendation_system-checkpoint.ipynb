# %%
# https://github.com/WillKoehrsen/wikipedia-data-science/blob/master/notebooks/Book%20Recommendation%20System.ipynb

import json
from itertools import chain
from collections import Counter, OrderedDict

# %%
books = []
with open('/data/jinkilee.github.io/found_books_filtered.ndjson', 'r') as fin:
    # Append each line to the books
    books = [json.loads(l) for l in fin]

# %%
# Remove non-book articles
books_with_wikipedia = [book for book in books if 'Wikipedia:' in book[0]]
books = [book for book in books if 'Wikipedia:' not in book[0]]
print('Found {} books.'.format(len(books)))
# Out:
# Found 37020 books.

# %%
[book[0] for book in books_with_wikipedia][:5]
# Out:
# ['Wikipedia:Wikipedia Signpost/2014-06-25/Recent research',
#  'Wikipedia:New pages patrol/Unpatrolled articles/December 2010',
#  'Wikipedia:Templates for discussion/Log/2012 September 23',
#  'Wikipedia:Articles for creation/Redirects/2012-10',
#  'Wikipedia:Templates for discussion/Log/2012 October 4']

# %%
book_index = {book[0]: idx for idx, book in enumerate(books)}
index_book = {idx: book for book, idx in book_index.items()}

book_index['Anna Karenina']
index_book[22494]
# Out:
# 'Anna Karenina'

# %%
wikilinks = list(chain(*[book[2] for book in books]))
print('There are {} unique wikilinks.'.format(len(set(wikilinks))))
# Out:
# There are 311276 unique wikilinks.

# %%
n = 21
books[n][2]
# Out:
# ['Emmanuel Carrère',
#  'biographical novel',
#  'Emmanuel Carrère',
#  'Eduard Limonov',
#  'Prix de la langue française',
#  'Prix Renaudot',
#  '2011 in literature',
#  'Contemporary French literature',
#  'Category:2011 French novels',
#  'Category:French biographies',
#  'Category:Biographical novels',
#  'Category:National Bolshevism']

# %%
wikilinks_other_books = [link for link in wikilinks if link in book_index.keys()]
print('There are {} unique wikilinks to other books.'.format(len(set(wikilinks_other_books))))
# Out:
# There are 17032 unique wikilinks to other books.

# %%
def count_items(l):
    """Return ordered dictionary of counts of objects in `l`"""
    
    # Create a counter object
    counts = Counter(l)
    
    # Sort by highest count first and place in ordered dictionary
    counts = sorted(counts.items(), key = lambda x: x[1], reverse = True)
    counts = OrderedDict(counts)
    
    return counts

# %%
# Find set of wikilinks for each book and convert to a flattened list
unique_wikilinks = list(chain(*[list(set(book[2])) for book in books]))

wikilink_counts = count_items(unique_wikilinks)
list(wikilink_counts.items())[:10]
# Out:
# [('Hardcover', 7489),
#  ('Paperback', 7311),
#  ('Wikipedia:WikiProject Books', 6043),
#  ('Wikipedia:WikiProject Novels', 6015),
#  ('English language', 4185),
#  ('United States', 3060),
#  ('Science fiction', 3030),
#  ('The New York Times', 2727),
#  ('science fiction', 2502),
#  ('novel', 1979)]

# %%
wikilinks = [link.lower() for link in unique_wikilinks]
print('There are {} unique wikilinks.'.format(len(set(wikilinks))))

wikilink_counts = count_items(wikilinks)
list(wikilink_counts.items())[:10]
# Out:
# There are 297624 unique wikilinks.
# [('paperback', 8740),
#  ('hardcover', 8648),
#  ('wikipedia:wikiproject books', 6043),
#  ('wikipedia:wikiproject novels', 6016),
#  ('science fiction', 5665),
#  ('english language', 4248),
#  ('united states', 3063),
#  ('novel', 2983),
#  ('the new york times', 2742),
#  ('fantasy', 2003)]

# %%
to_remove = ['hardcover', 'paperback', 'hardback', 'e-book', 'wikipedia:wikiproject books', 'wikipedia:wikiproject novels']
for t in to_remove:
    wikilinks.remove(t)
    _ = wikilink_counts.pop(t)

# %%
# Limit to greater than 3 links
links = [t[0] for t in wikilink_counts.items() if t[1] >= 4]
print(len(links))
# Out:
# 41758

# %%
# Find set of book wikilinks for each book
unique_wikilinks_books = list(chain(*[list(set(link for link in book[2] if link in book_index.keys())) for book in books]))

# Count the number of books linked to by other books
wikilink_book_counts = count_items(unique_wikilinks_books)
list(wikilink_book_counts.items())[:10]
# Out:
# [('The Encyclopedia of Science Fiction', 127),
#  ('The Discontinuity Guide', 104),
#  ('The Encyclopedia of Fantasy', 63),
#  ('Dracula', 55),
#  ('Encyclopædia Britannica', 51),
#  ('Nineteen Eighty-Four', 51),
#  ('The Wonderful Wizard of Oz', 49),
#  ('Don Quixote', 49),
#  ("Alice's Adventures in Wonderland", 47),
#  ('Jane Eyre', 39)]

# %%
for book in books:
    if 'The New York Times' in book[2] and 'New York Times' in book[2]:
        print(book[0], book[2])
        break
# Out:
# The Big Picture: Who Killed Hollywood? and Other Essays ['Wikipedia:WikiProject Novels', 'Wikipedia:WikiProject Books', 'William Goldman', 'United States', 'English language', 'William Goldman', 'Michael Sragow', 'Good Will Hunting', 'Robin Williams', 'Matt Damon', 'The New York Times', 'The New York Times Company', 'New York Times', 'Category:Cinema of the United States', 'Category:Film production', 'Category:2000 books', 'Category:Books about films', 'Category:Books by William Goldman', 'Category:Show business memoirs']

# %%
link_index = {link: idx for idx, link in enumerate(links)}
index_link = {idx: link for link, idx in link_index.items()}

link_index['the economist']
index_link[300]
print('There are {} wikilinks that will be used.'.format(len(link_index)))
# Out:
# There are 41758 wikilinks that will be used.

# %% [markdown]
# # supervised learning

# %%
pairs = []

# Iterate through each book
for i, book in enumerate(books):
    if i%100 == 0:
        print('%dth iteration is finished' % i)
    # Iterate through the links in the book
    pairs.extend((book_index[book[0]], link_index[link.lower()]) for link in book[2] if link.lower() in links)
    
len(pairs), len(links), len(books)
pairs[5000]
# Out:
# 0th iteration is finished
# 100th iteration is finished
# 200th iteration is finished
# 300th iteration is finished
# 400th iteration is finished
# 500th iteration is finished
# 600th iteration is finished
# 700th iteration is finished
# 800th iteration is finished
# 900th iteration is finished
# 1000th iteration is finished
# 1100th iteration is finished
# 1200th iteration is finished
# 1300th iteration is finished
# 1400th iteration is finished
# 1500th iteration is finished
# 1600th iteration is finished
# 1700th iteration is finished
# 1800th iteration is finished
# 1900th iteration is finished
# 2000th iteration is finished
# 2100th iteration is finished
# 2200th iteration is finished
# 2300th iteration is finished
# 2400th iteration is finished
# 2500th iteration is finished
# 2600th iteration is finished
# 2700th iteration is finished
# 2800th iteration is finished
# 2900th iteration is finished
# 3000th iteration is finished
# 3100th iteration is finished
# 3200th iteration is finished
# 3300th iteration is finished
# 3400th iteration is finished
# 3500th iteration is finished
# 3600th iteration is finished
# 3700th iteration is finished
# 3800th iteration is finished
# 3900th iteration is finished
# 4000th iteration is finished
# 4100th iteration is finished
# 4200th iteration is finished
# 4300th iteration is finished
# 4400th iteration is finished
# 4500th iteration is finished
# 4600th iteration is finished
# 4700th iteration is finished
# 4800th iteration is finished
# 4900th iteration is finished
# 5000th iteration is finished
# 5100th iteration is finished
# 5200th iteration is finished
# 5300th iteration is finished
# 5400th iteration is finished
# 5500th iteration is finished
# 5600th iteration is finished
# 5700th iteration is finished
# 5800th iteration is finished
# 5900th iteration is finished
# 6000th iteration is finished
# 6100th iteration is finished
# 6200th iteration is finished
# 6300th iteration is finished
# 6400th iteration is finished
# 6500th iteration is finished
# 6600th iteration is finished
# 6700th iteration is finished
# 6800th iteration is finished
# 6900th iteration is finished
# 7000th iteration is finished
# 7100th iteration is finished
# 7200th iteration is finished
# 7300th iteration is finished
# 7400th iteration is finished
# 7500th iteration is finished
# 7600th iteration is finished
# 7700th iteration is finished
# 7800th iteration is finished
# 7900th iteration is finished
# 8000th iteration is finished
# 8100th iteration is finished
# 8200th iteration is finished
# 8300th iteration is finished
# 8400th iteration is finished
# 8500th iteration is finished
# 8600th iteration is finished
# 8700th iteration is finished
# 8800th iteration is finished
# 8900th iteration is finished
# 9000th iteration is finished
# 9100th iteration is finished
# 9200th iteration is finished
# 9300th iteration is finished
# 9400th iteration is finished
# 9500th iteration is finished
# 9600th iteration is finished
# 9700th iteration is finished
# 9800th iteration is finished
# 9900th iteration is finished
# 10000th iteration is finished
# 10100th iteration is finished
# 10200th iteration is finished
# 10300th iteration is finished
# 10400th iteration is finished
# 10500th iteration is finished
# 10600th iteration is finished
# 10700th iteration is finished
# 10800th iteration is finished
# 10900th iteration is finished
# 11000th iteration is finished
# 11100th iteration is finished
# 11200th iteration is finished
# 11300th iteration is finished
# 11400th iteration is finished
# 11500th iteration is finished
# 11600th iteration is finished
# 11700th iteration is finished
# 11800th iteration is finished
# 11900th iteration is finished
# 12000th iteration is finished
# 12100th iteration is finished
# 12200th iteration is finished
# 12300th iteration is finished
# 12400th iteration is finished
# 12500th iteration is finished
# 12600th iteration is finished
# 12700th iteration is finished
# 12800th iteration is finished
# 12900th iteration is finished
# 13000th iteration is finished
# 13100th iteration is finished
# 13200th iteration is finished
# 13300th iteration is finished
# 13400th iteration is finished
# 13500th iteration is finished
# 13600th iteration is finished
# 13700th iteration is finished
# 13800th iteration is finished
# 13900th iteration is finished
# 14000th iteration is finished
# 14100th iteration is finished
# 14200th iteration is finished
# 14300th iteration is finished
# 14400th iteration is finished
# 14500th iteration is finished
# 14600th iteration is finished
# 14700th iteration is finished
# 14800th iteration is finished
# 14900th iteration is finished
# 15000th iteration is finished
# 15100th iteration is finished
# 15200th iteration is finished
# 15300th iteration is finished
# 15400th iteration is finished
# 15500th iteration is finished
# 15600th iteration is finished
# 15700th iteration is finished
# 15800th iteration is finished
# 15900th iteration is finished
# 16000th iteration is finished
# 16100th iteration is finished
# 16200th iteration is finished
# 16300th iteration is finished
# 16400th iteration is finished
# 16500th iteration is finished
# 16600th iteration is finished
# 16700th iteration is finished
# 16800th iteration is finished
# 16900th iteration is finished
# 17000th iteration is finished
# 17100th iteration is finished
# 17200th iteration is finished
# 17300th iteration is finished
# 17400th iteration is finished
# 17500th iteration is finished
# 17600th iteration is finished
# 17700th iteration is finished
# 17800th iteration is finished
# 17900th iteration is finished
# 18000th iteration is finished
# 18100th iteration is finished
# 18200th iteration is finished
# 18300th iteration is finished
# 18400th iteration is finished
# 18500th iteration is finished
# 18600th iteration is finished
# 18700th iteration is finished
# 18800th iteration is finished
# 18900th iteration is finished
# 19000th iteration is finished
# 19100th iteration is finished
# 19200th iteration is finished
# 19300th iteration is finished
# 19400th iteration is finished
# 19500th iteration is finished
# 19600th iteration is finished
# 19700th iteration is finished
# 19800th iteration is finished
# 19900th iteration is finished
# 20000th iteration is finished
# 20100th iteration is finished
# 20200th iteration is finished
# 20300th iteration is finished
# 20400th iteration is finished
# 20500th iteration is finished
# 20600th iteration is finished
# 20700th iteration is finished
# 20800th iteration is finished
# 20900th iteration is finished
# 21000th iteration is finished
# 21100th iteration is finished
# 21200th iteration is finished
# 21300th iteration is finished
# 21400th iteration is finished
# 21500th iteration is finished
# 21600th iteration is finished
# 21700th iteration is finished
# 21800th iteration is finished
# 21900th iteration is finished
# 22000th iteration is finished
# 22100th iteration is finished
# 22200th iteration is finished
# 22300th iteration is finished
# 22400th iteration is finished
# 22500th iteration is finished
# 22600th iteration is finished
# 22700th iteration is finished
# 22800th iteration is finished
# 22900th iteration is finished
# 23000th iteration is finished
# 23100th iteration is finished
# 23200th iteration is finished
# 23300th iteration is finished
# 23400th iteration is finished
# 23500th iteration is finished
# 23600th iteration is finished
# 23700th iteration is finished
# 23800th iteration is finished
# 23900th iteration is finished
# 24000th iteration is finished
# 24100th iteration is finished
# 24200th iteration is finished
# 24300th iteration is finished
# 24400th iteration is finished
# 24500th iteration is finished
# 24600th iteration is finished
# 24700th iteration is finished
# 24800th iteration is finished
# 24900th iteration is finished
# 25000th iteration is finished
# 25100th iteration is finished
# 25200th iteration is finished
# 25300th iteration is finished
# 25400th iteration is finished
# 25500th iteration is finished
# 25600th iteration is finished
# 25700th iteration is finished
# 25800th iteration is finished
# 25900th iteration is finished
# 26000th iteration is finished
# 26100th iteration is finished
# 26200th iteration is finished
# 26300th iteration is finished
# 26400th iteration is finished
# 26500th iteration is finished
# 26600th iteration is finished
# 26700th iteration is finished
# 26800th iteration is finished
# 26900th iteration is finished
# 27000th iteration is finished
# 27100th iteration is finished
# 27200th iteration is finished
# 27300th iteration is finished
# 27400th iteration is finished
# 27500th iteration is finished
# 27600th iteration is finished
# 27700th iteration is finished
# 27800th iteration is finished
# 27900th iteration is finished
# 28000th iteration is finished
# 28100th iteration is finished
# 28200th iteration is finished
# 28300th iteration is finished
# 28400th iteration is finished
# 28500th iteration is finished
# 28600th iteration is finished
# 28700th iteration is finished
# 28800th iteration is finished
# 28900th iteration is finished
# 29000th iteration is finished
# 29100th iteration is finished
# 29200th iteration is finished
# 29300th iteration is finished
# 29400th iteration is finished
# 29500th iteration is finished
# 29600th iteration is finished
# 29700th iteration is finished
# 29800th iteration is finished
# 29900th iteration is finished
# 30000th iteration is finished
# 30100th iteration is finished
# 30200th iteration is finished
# 30300th iteration is finished
# 30400th iteration is finished
# 30500th iteration is finished
# 30600th iteration is finished
# 30700th iteration is finished
# 30800th iteration is finished
# 30900th iteration is finished
# 31000th iteration is finished
# 31100th iteration is finished
# 31200th iteration is finished
# 31300th iteration is finished
# 31400th iteration is finished
# 31500th iteration is finished
# 31600th iteration is finished
# 31700th iteration is finished
# 31800th iteration is finished
# 31900th iteration is finished
# 32000th iteration is finished
# 32100th iteration is finished
# 32200th iteration is finished
# 32300th iteration is finished
# 32400th iteration is finished
# 32500th iteration is finished
# 32600th iteration is finished
# 32700th iteration is finished
# 32800th iteration is finished
# 32900th iteration is finished
# 33000th iteration is finished
# 33100th iteration is finished
# 33200th iteration is finished
# 33300th iteration is finished
# 33400th iteration is finished
# 33500th iteration is finished
# 33600th iteration is finished
# 33700th iteration is finished
# 33800th iteration is finished
# 33900th iteration is finished
# 34000th iteration is finished
# 34100th iteration is finished
# 34200th iteration is finished
# 34300th iteration is finished
# 34400th iteration is finished
# 34500th iteration is finished
# 34600th iteration is finished
# 34700th iteration is finished
# 34800th iteration is finished
# 34900th iteration is finished
# 35000th iteration is finished
# 35100th iteration is finished
# 35200th iteration is finished
# 35300th iteration is finished
# 35400th iteration is finished
# 35500th iteration is finished
# 35600th iteration is finished
# 35700th iteration is finished
# 35800th iteration is finished
# 35900th iteration is finished
# 36000th iteration is finished
# 36100th iteration is finished
# 36200th iteration is finished
# 36300th iteration is finished
# 36400th iteration is finished
# 36500th iteration is finished
# 36600th iteration is finished
# 36700th iteration is finished
# 36800th iteration is finished
# 36900th iteration is finished
# 37000th iteration is finished
# (321, 232)

# %%
pairs_set = set(pairs)

# %%
x = Counter(pairs)
sorted(x.items(), key = lambda x: x[1], reverse = True)[:5]
# Out:
# [((13337, 26946), 85),
#  ((31899, 65), 77),
#  ((25899, 9233), 61),
#  ((1851, 2648), 57),
#  ((25899, 27804), 53)]

# %%
import numpy as np
import random
random.seed(100)

def generate_batch(pairs, n_positive = 50, negative_ratio = 1.0, classification = False):
    """Generate batches of samples for training"""
    batch_size = n_positive * (1 + negative_ratio)
    batch = np.zeros((batch_size, 3))
    
    # Adjust label based on task
    if classification:
        neg_label = 0
    else:
        neg_label = -1
    
    # This creates a generator
    while True:
        # randomly choose positive examples
        for idx, (book_id, link_id) in enumerate(random.sample(pairs, n_positive)):
            batch[idx, :] = (book_id, link_id, 1)

        # Increment idx by 1
        idx += 1
        
        # Add negative examples until reach batch size
        while idx < batch_size:
            
            # random selection
            random_book = random.randrange(len(books))
            random_link = random.randrange(len(links))
            
            # Check to make sure this is not a positive example
            if (random_book, random_link) not in pairs_set:
                
                # Add to batch and increment index
                batch[idx, :] = (random_book, random_link, neg_label)
                idx += 1
                
        # Make sure to shuffle order
        np.random.shuffle(batch)
        yield {'book': batch[:, 0], 'link': batch[:, 1]}, batch[:, 2]
