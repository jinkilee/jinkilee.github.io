# %%
import sys
sys.path.insert(0, '../'); del sys

# %%
import io
import re
import os
import time
import numpy as np
import unicodedata
import tensorflow as tf
from sklearn.model_selection import train_test_split
from models import Encoder, Decoder
from models import BahdanauAttention
from absl import logging
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# set logging condition
logging.set_verbosity(logging.INFO)
logging.set_verbosity(logging.DEBUG)

# %%
BATCH_SIZE = 64
embedding_dim = 128
units = 512

# %%
def unicode_to_ascii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s) if unicodedata.category(c) != 'Mn')

def preprocess_eng(w):
    w = unicode_to_ascii(w.lower().strip())

    # replace substring
    w = re.sub(r"([?.!,¿])", r" \1 ", w)
    w = re.sub(r'[" "]+', " ", w)
    w = re.sub(r"[^a-zA-Z?.!,¿]+", " ", w)
    w = w.rstrip().strip()

    # add start/end tags
    w = '<start> ' + w + ' <end>'
    return w

def preprocess_kor(w):
    # replace substring
    w = re.sub(r'([?.!,¿])', r' \1 ', w)
    w = re.sub(r'[" "]+', ' ', w)
    w = re.sub(r'[^ ㄱ-ㅣ가-힣]+', ' ', w)
    w = w.rstrip().strip()

    # add start/end tags
    w = '<start> ' + w + ' <end>'
    return w

def read_data(filename):
    lines = io.open(filename, encoding='UTF-8').read().strip().split('\n')
    word_pairs = np.array([l.rstrip().split('\t') for l in lines])
    eng = list(map(preprocess_eng, word_pairs[:, 0]))
    kor = list(map(preprocess_kor, word_pairs[:, 1]))
    return eng, kor

def tokenize(sent):
    sent_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
    sent_tokenizer.fit_on_texts(sent)

    sequences = sent_tokenizer.texts_to_sequences(sent)
    sequences = tf.keras.preprocessing.sequence.pad_sequences(sequences, padding='post')
    return sequences, sent_tokenizer

# %%
# read dataset
en, kr = read_data('/data/nmt/corpus.txt')
en_seq, en_tok = tokenize(en)
kr_seq, kr_tok = tokenize(kr)
en_seq_train, en_seq_val, kr_seq_train, kr_seq_val = train_test_split(en_seq, kr_seq, test_size=0.1)

# %%
# make tf.dataset
BUFFER_SIZE = len(en_seq_train)
steps_per_epoch = len(en_seq_train) // BATCH_SIZE
dataset = tf.data.Dataset.from_tensor_slices((en_seq_train, kr_seq_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 101]), TensorShape([64, 63]))

# %%
# make encoder
vocab_inp_size = len(en_tok.word_index) + 1
vocab_tar_size = len(kr_tok.word_index) + 1
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)
attention_layer = BahdanauAttention(10)

# %%
# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)
sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)), sample_hidden, sample_output)
attention_result, attention_weights = attention_layer(sample_hidden, sample_output)
logging.debug('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
logging.debug('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
logging.debug('Attention result shape: (batch size, units) {}'.format(attention_result.shape))
logging.debug('Attention weights shape: (batch_size, sequence_length, 1) {}'.format(attention_weights.shape))
logging.debug('Decoder output shape: (batch_size, vocab size) {}'.format(sample_decoder_output.shape))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# I0606 00:38:59.968358 140592723191552 <ipython-input-10-c56056e15080>:6] Encoder Hidden state shape: (batch size, units) (64, 512)
# I0606 00:38:59.969199 140592723191552 <ipython-input-10-c56056e15080>:7] Encoder output shape: (batch size, sequence length, units) (64, 101, 512)
# I0606 00:38:59.969748 140592723191552 <ipython-input-10-c56056e15080>:8] Attention result shape: (batch size, units) (64, 512)
# I0606 00:38:59.970262 140592723191552 <ipython-input-10-c56056e15080>:9] Attention weights shape: (batch_size, sequence_length, 1) (64, 101, 1)
# I0606 00:38:59.970654 140592723191552 <ipython-input-10-c56056e15080>:10] Decoder output shape: (batch_size, vocab size) (64, 191645)

# %%
# optimizer
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

# %%
def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)
    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
    loss = 0

    with tf.GradientTape() as tape:
        enc_output, enc_hidden = encoder(inp, enc_hidden)
        dec_hidden = enc_hidden
        dec_input = tf.expand_dims([kr_tok.word_index['<start>']] * BATCH_SIZE, 1)

        # Teacher forcing - feeding the target as the next input
        for t in range(1, targ.shape[1]):
            # passing enc_output to the decoder
            predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)
            loss += loss_function(targ[:, t], predictions)
            # using teacher forcing
            dec_input = tf.expand_dims(targ[:, t], 1)
            print(t, predictions, dec_hidden)

    batch_loss = (loss / int(targ.shape[1]))
    variables = encoder.trainable_variables + decoder.trainable_variables
    gradients = tape.gradient(loss, variables)
    optimizer.apply_gradients(zip(gradients, variables))
    return batch_loss

# %%
checkpoint_dir = '/data/nmt/training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer, encoder=encoder, decoder=decoder)

# %%
EPOCHS = 100
for epoch in range(EPOCHS):
    start = time.time()

    enc_hidden = encoder.initialize_hidden_state()
    total_loss = 0

    for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
        batch_loss = train_step(inp, targ, enc_hidden)
        total_loss += batch_loss

    # saving (checkpoint) the model every 2 epochs
    if (epoch + 1) % 2 == 0:
        checkpoint.save(file_prefix = checkpoint_prefix)

    #print('Epoch {} Loss {:.4f}'.format(epoch + 1, total_loss / steps_per_epoch))
    logging.info('epoch {} loss {:.4f} -> {:.4f} taken'.format(
        epoch+1, total_loss/steps_per_epoch, time.time()-start))
# Out:
# 1 Tensor("decoder/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 2 Tensor("decoder_1/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_1/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 3 Tensor("decoder_2/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_2/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 4 Tensor("decoder_3/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_3/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 5 Tensor("decoder_4/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_4/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 6 Tensor("decoder_5/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_5/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 7 Tensor("decoder_6/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_6/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 8 Tensor("decoder_7/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_7/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 9 Tensor("decoder_8/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_8/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 10 Tensor("decoder_9/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_9/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 11 Tensor("decoder_10/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_10/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 12 Tensor("decoder_11/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_11/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 13 Tensor("decoder_12/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_12/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 14 Tensor("decoder_13/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_13/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 15 Tensor("decoder_14/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_14/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 16 Tensor("decoder_15/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_15/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 17 Tensor("decoder_16/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_16/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 18 Tensor("decoder_17/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_17/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 19 Tensor("decoder_18/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_18/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 20 Tensor("decoder_19/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_19/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 21 Tensor("decoder_20/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_20/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 22 Tensor("decoder_21/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_21/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 23 Tensor("decoder_22/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_22/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 24 Tensor("decoder_23/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_23/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 25 Tensor("decoder_24/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_24/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 26 Tensor("decoder_25/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_25/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 27 Tensor("decoder_26/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_26/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 28 Tensor("decoder_27/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_27/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 29 Tensor("decoder_28/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_28/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 30 Tensor("decoder_29/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_29/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 31 Tensor("decoder_30/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_30/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 32 Tensor("decoder_31/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_31/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 33 Tensor("decoder_32/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_32/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 34 Tensor("decoder_33/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_33/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 35 Tensor("decoder_34/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_34/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 36 Tensor("decoder_35/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_35/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 37 Tensor("decoder_36/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_36/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 38 Tensor("decoder_37/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_37/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 39 Tensor("decoder_38/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_38/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 40 Tensor("decoder_39/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_39/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 41 Tensor("decoder_40/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_40/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 42 Tensor("decoder_41/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_41/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 43 Tensor("decoder_42/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_42/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 44 Tensor("decoder_43/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_43/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 45 Tensor("decoder_44/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_44/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 46 Tensor("decoder_45/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_45/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 47 Tensor("decoder_46/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_46/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 48 Tensor("decoder_47/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_47/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 49 Tensor("decoder_48/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_48/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 50 Tensor("decoder_49/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_49/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 51 Tensor("decoder_50/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_50/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 52 Tensor("decoder_51/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_51/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 53 Tensor("decoder_52/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_52/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 54 Tensor("decoder_53/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_53/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 55 Tensor("decoder_54/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_54/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 56 Tensor("decoder_55/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_55/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 57 Tensor("decoder_56/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_56/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 58 Tensor("decoder_57/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_57/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 59 Tensor("decoder_58/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_58/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 60 Tensor("decoder_59/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_59/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 61 Tensor("decoder_60/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_60/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 62 Tensor("decoder_61/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_61/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 1 Tensor("decoder/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 2 Tensor("decoder_1/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_1/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 3 Tensor("decoder_2/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_2/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 4 Tensor("decoder_3/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_3/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 5 Tensor("decoder_4/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_4/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 6 Tensor("decoder_5/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_5/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 7 Tensor("decoder_6/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_6/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 8 Tensor("decoder_7/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_7/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 9 Tensor("decoder_8/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_8/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 10 Tensor("decoder_9/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_9/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 11 Tensor("decoder_10/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_10/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 12 Tensor("decoder_11/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_11/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 13 Tensor("decoder_12/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_12/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 14 Tensor("decoder_13/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_13/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 15 Tensor("decoder_14/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_14/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 16 Tensor("decoder_15/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_15/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 17 Tensor("decoder_16/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_16/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 18 Tensor("decoder_17/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_17/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 19 Tensor("decoder_18/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_18/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 20 Tensor("decoder_19/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_19/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 21 Tensor("decoder_20/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_20/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 22 Tensor("decoder_21/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_21/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 23 Tensor("decoder_22/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_22/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 24 Tensor("decoder_23/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_23/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 25 Tensor("decoder_24/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_24/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 26 Tensor("decoder_25/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_25/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 27 Tensor("decoder_26/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_26/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 28 Tensor("decoder_27/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_27/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 29 Tensor("decoder_28/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_28/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 30 Tensor("decoder_29/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_29/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 31 Tensor("decoder_30/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_30/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 32 Tensor("decoder_31/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_31/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 33 Tensor("decoder_32/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_32/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 34 Tensor("decoder_33/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_33/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 35 Tensor("decoder_34/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_34/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 36 Tensor("decoder_35/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_35/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 37 Tensor("decoder_36/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_36/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 38 Tensor("decoder_37/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_37/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 39 Tensor("decoder_38/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_38/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 40 Tensor("decoder_39/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_39/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 41 Tensor("decoder_40/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_40/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 42 Tensor("decoder_41/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_41/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 43 Tensor("decoder_42/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_42/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 44 Tensor("decoder_43/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_43/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 45 Tensor("decoder_44/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_44/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 46 Tensor("decoder_45/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_45/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 47 Tensor("decoder_46/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_46/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 48 Tensor("decoder_47/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_47/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 49 Tensor("decoder_48/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_48/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 50 Tensor("decoder_49/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_49/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 51 Tensor("decoder_50/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_50/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 52 Tensor("decoder_51/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_51/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 53 Tensor("decoder_52/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_52/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 54 Tensor("decoder_53/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_53/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 55 Tensor("decoder_54/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_54/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 56 Tensor("decoder_55/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_55/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 57 Tensor("decoder_56/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_56/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 58 Tensor("decoder_57/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_57/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 59 Tensor("decoder_58/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_58/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 60 Tensor("decoder_59/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_59/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 61 Tensor("decoder_60/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_60/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
# 62 Tensor("decoder_61/dense/BiasAdd:0", shape=(64, 191645), dtype=float32) Tensor("decoder_61/unified_gru_1/while/Identity_4:0", shape=(64, 512), dtype=float32)
